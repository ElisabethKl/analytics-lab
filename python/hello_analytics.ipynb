# %% [markdown]
# # Analytics Lab
# My first Python notebook.
# This environment was created as part of my data analytics learning journey.

# %%
print("Analytics Lab")
# Out:
# Analytics Lab

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\elisa\Projects\analytics-lab\.venv\Scripts\python.exe
